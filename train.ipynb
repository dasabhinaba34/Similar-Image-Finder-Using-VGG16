# %%
pip install imutils
# Out:
# Requirement already satisfied: imutils in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (0.5.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (2.10.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: numpy>=1.20 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: libclang>=13.0.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: packaging in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: six>=1.12.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: setuptools in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (61.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (22.9.24)
# Requirement already satisfied: h5py>=2.9.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.33.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.27.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.0.3)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.9)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from packaging->tensorflow) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.19.3 in /Users/abhinabadas/opt/anaconda3/lib/python3.9/site-packages (from opencv-python) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from imutils import paths
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input
import numpy as np
import pandas as pd

config={"BATCH_SIZE":32, "DATASET_LOCATION":'dataset/', "FEATURES_OUTPUT":"features.csv"}

#Listing the paths of all our images
imagePaths=list(paths.list_images(config["DATASET_LOCATION"]))

#Loading our pretrained model
model=VGG16(weights="imagenet",include_top=False)

#Extracting the labels from the images
labels={}
for (i,imagepath) in enumerate(imagePaths):
    labels[i]=imagepath.split('/')[1]


    
stack_features=[]

#Loop over the images in batches
for (b,i) in enumerate(range(0,len(imagePaths),config["BATCH_SIZE"])):
    
    print("[INFO] processing batch {}/{}".format(b + 1,
          int(np.ceil(len(imagePaths) / float(config["BATCH_SIZE"])))))
    #Extracting the batch of images
    batchPaths=imagePaths[i:i+config["BATCH_SIZE"]]
    
    images=[]
    
    for path in batchPaths:
        
        #Load the image  while ensuring the image is resized to 224x224 pixels
        image=load_img(path,target_size=(224,224))
        image=img_to_array(image)
        
        #Preprocess the image
        image = np.expand_dims(image, axis=0)
        image=preprocess_input(image)
        
        
        images.append(image)

    # pass the images through the network and use the outputs as
    # our actual features, then reshape the features into a
    batchImages = np.vstack(images)
    features=model.predict(batchImages,batch_size=10)
    features = features.reshape((features.shape[0], 7 * 7 * 512))
    stack_features.append(features)
    
features_matrix=np.vstack(stack_features)

#Processing the column names
cols=[]
for i in range(features_matrix.shape[1]):
    col_name="F{}".format(i)
    cols.append(col_name)
    
#Making a Dataframe with our features    
dframe=pd.DataFrame(data=features_matrix,columns=cols)

#Writing the features to a .csv file
dframe.to_csv(config["FEATURES_OUTPUT"],index=False)
# Out:
# 2022-11-10 14:44:16.705698: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-10 14:44:31.905095: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [INFO] processing batch 1/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 2/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 3/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 4/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 5/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 6/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 7/149
# 4/4 [==============================] - 12s 2s/step
# [INFO] processing batch 8/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 9/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 10/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 11/149
# 4/4 [==============================] - 11s 2s/step
# [INFO] processing batch 12/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 13/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 14/149
# 4/4 [==============================] - 12s 3s/step
# [INFO] processing batch 15/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 16/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 17/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 18/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 19/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 20/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 21/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 22/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 23/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 24/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 25/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 26/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 27/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 28/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 29/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 30/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 31/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 32/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 33/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 34/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 35/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 36/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 37/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 38/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 39/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 40/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 41/149
# 4/4 [==============================] - 11s 2s/step
# [INFO] processing batch 42/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 43/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 44/149
# 4/4 [==============================] - 11s 2s/step
# [INFO] processing batch 45/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 46/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 47/149
# 4/4 [==============================] - 11s 2s/step
# [INFO] processing batch 48/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 49/149
# 4/4 [==============================] - 11s 2s/step
# [INFO] processing batch 50/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 51/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 52/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 53/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 54/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 55/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 56/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 57/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 58/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 59/149
# 4/4 [==============================] - 11s 2s/step
# [INFO] processing batch 60/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 61/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 62/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 63/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 64/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 65/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 66/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 67/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 68/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 69/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 70/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 71/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 72/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 73/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 74/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 75/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 76/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 77/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 78/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 79/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 80/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 81/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 82/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 83/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 84/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 85/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 86/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 87/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 88/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 89/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 90/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 91/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 92/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 93/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 94/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 95/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 96/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 97/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 98/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 99/149
# 4/4 [==============================] - 10s 3s/step
# [INFO] processing batch 100/149
# 4/4 [==============================] - 12s 3s/step
# [INFO] processing batch 101/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 102/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 103/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 104/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 105/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 106/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 107/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 108/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 109/149
# 4/4 [==============================] - 11s 2s/step
# [INFO] processing batch 110/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 111/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 112/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 113/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 114/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 115/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 116/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 117/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 118/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 119/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 120/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 121/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 122/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 123/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 124/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 125/149
# 4/4 [==============================] - 11s 2s/step
# [INFO] processing batch 126/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 127/149
# 4/4 [==============================] - 12s 2s/step
# [INFO] processing batch 128/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 129/149
# 4/4 [==============================] - 11s 2s/step
# [INFO] processing batch 130/149
# 4/4 [==============================] - 12s 2s/step
# [INFO] processing batch 131/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 132/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 133/149
# 4/4 [==============================] - 9s 2s/step
# [INFO] processing batch 134/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 135/149
# 4/4 [==============================] - 12s 3s/step
# [INFO] processing batch 136/149
# 4/4 [==============================] - 14s 3s/step
# [INFO] processing batch 137/149
# 4/4 [==============================] - 15s 3s/step
# [INFO] processing batch 138/149
# 4/4 [==============================] - 13s 3s/step
# [INFO] processing batch 139/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 140/149
# 4/4 [==============================] - 18s 4s/step
# [INFO] processing batch 141/149
# 4/4 [==============================] - 14s 3s/step
# [INFO] processing batch 142/149
# 4/4 [==============================] - 12s 3s/step
# [INFO] processing batch 143/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 144/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 145/149
# 4/4 [==============================] - 12s 3s/step
# [INFO] processing batch 146/149
# 4/4 [==============================] - 11s 2s/step
# [INFO] processing batch 147/149
# 4/4 [==============================] - 10s 2s/step
# [INFO] processing batch 148/149
# 4/4 [==============================] - 11s 3s/step
# [INFO] processing batch 149/149
# 1/1 [==============================] - 1s 713ms/step
